# %%
import pandas as pd

df = pd.read_csv("../raw/news_raw.csv")
df.head()
# Out:
#   source_name author                                              title  \
# 0       GNews    NaN  Why the Indo-Pacific needs to be central to In...
# 1       GNews    NaN  Beyond political reshuffles, renew education i...
# 2       GNews    NaN  India vs England: Doors closing down fast on R...
# 3       GNews    NaN    Is OnePlus exiting India? Explained - The Hindu
# 4       GNews    NaN  India to face Malaysia, Syria, Iraq in AFC U17...
#
#                                          description  \
# 0  Why the Indo-Pacific needs to be central to In...
# 1  Beyond political reshuffles, renew education i...
# 2  India vs England: Doors closing down fast on R...
# 3     Is OnePlus exiting India? Explained  The Hindu
# 4  India to face Malaysia, Syria, Iraq in AFC U17...
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMilgFBV...
# 1  https://news.google.com/rss/articles/CBMirwFBV...
# ...

# %%
df.head()
# Out:
#   source_name author                                              title  \
# 0       GNews    NaN  Why the Indo-Pacific needs to be central to In...
# 1       GNews    NaN  Beyond political reshuffles, renew education i...
# 2       GNews    NaN  India vs England: Doors closing down fast on R...
# 3       GNews    NaN    Is OnePlus exiting India? Explained - The Hindu
# 4       GNews    NaN  India to face Malaysia, Syria, Iraq in AFC U17...
#
#                                          description  \
# 0  Why the Indo-Pacific needs to be central to In...
# 1  Beyond political reshuffles, renew education i...
# 2  India vs England: Doors closing down fast on R...
# 3     Is OnePlus exiting India? Explained  The Hindu
# 4  India to face Malaysia, Syria, Iraq in AFC U17...
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMilgFBV...
# 1  https://news.google.com/rss/articles/CBMirwFBV...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   source_name     509 non-null    object
#  1   author          99 non-null     object
#  2   title           509 non-null    object
#  3   description     509 non-null    object
#  4   url             509 non-null    object
#  5   keyword         509 non-null    object
#  6   language        509 non-null    object
#  7   published_date  509 non-null    object
#  8   collected_at    509 non-null    object
# dtypes: object(9)
# memory usage: 35.9+ KB

# %%
df.describe(include="all")
# Out:
#             source_name          author  \
# count               509              99
# unique                5              39
# top     Hindustan Times  TOI WORLD DESK
# freq                164              17
#
#                                                   title  \
# count                                               509
# unique                                              507
# top     Rejuvenated India aim to seal series - Cricbuzz
# freq                                                  2
#
#                                               description  \
# count                                                 509
# unique                                                509
# top     Why the Indo-Pacific needs to be central to In...
# freq                                                    1
#
#                                                       url             keyword  \
# count                                                 509                 509
# ...

# %%
df.shape
# Out:
# (509, 9)

# %%
df.isnull().sum()
# Out:
# source_name         0
# author            410
# title               0
# description         0
# url                 0
# keyword             0
# language            0
# published_date      0
# collected_at        0
# dtype: int64

# %%
df["author"] = df["author"].fillna("Unknown")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates(subset=["title"])

# %%
import re

def clean_text(text):
    text = str(text)
    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^a-zA-Z0-9 ]", "", text)
    text = text.strip()
    return text

df["title"] = df["title"].apply(clean_text)

# %%
df.head(5)
# Out:
#   source_name   author                                              title  \
# 0       GNews  Unknown  why the indopacific needs to be central to ind...
# 1       GNews  Unknown  beyond political reshuffles renew education in...
# 2       GNews  Unknown  india vs england doors closing down fast on ro...
# 3       GNews  Unknown      is oneplus exiting india explained  the hindu
# 4       GNews  Unknown  india to face malaysia syria iraq in afc u17 w...
#
#                                          description  \
# 0  Why the Indo-Pacific needs to be central to In...
# 1  Beyond political reshuffles, renew education i...
# 2  India vs England: Doors closing down fast on R...
# 3     Is OnePlus exiting India? Explained  The Hindu
# 4  India to face Malaysia, Syria, Iraq in AFC U17...
#
#                                                  url  \
# 0  https://news.google.com/rss/articles/CBMilgFBV...
# 1  https://news.google.com/rss/articles/CBMirwFBV...
# ...

# %%
df["description"] = df["description"].apply(clean_text)

# %%
df["published_date"] = pd.to_datetime(df["published_date"])

# %%
df["year"] = df["published_date"].dt.year
df["month"] = df["published_date"].dt.month
df["day"] = df["published_date"].dt.day
df["weekday"] = df["published_date"].dt.day_name()

# %%
df = df[df["url"].str.startswith("http", na=False)]

# %%
df = df[df["title"].str.len() > 5]

# %%
df["language"] = df["language"].str.lower()

# %%
df.info()

df.isnull().sum()

df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 507 entries, 0 to 508
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   source_name     507 non-null    object
#  1   author          507 non-null    object
#  2   title           507 non-null    object
#  3   description     507 non-null    object
#  4   url             507 non-null    object
#  5   keyword         507 non-null    object
#  6   language        507 non-null    object
#  7   published_date  507 non-null    datetime64[ns]
#  8   collected_at    507 non-null    object
#  9   year            507 non-null    int32
#  10  month           507 non-null    int32
#  11  day             507 non-null    int32
#  12  weekday         507 non-null    object
# dtypes: datetime64[ns](1), int32(3), object(9)
# memory usage: 49.5+ KB
# (507, 13)

# %%
df["collected_at"] = pd.to_datetime(df["collected_at"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 507 entries, 0 to 508
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   source_name     507 non-null    object
#  1   author          507 non-null    object
#  2   title           507 non-null    object
#  3   description     507 non-null    object
#  4   url             507 non-null    object
#  5   keyword         507 non-null    object
#  6   language        507 non-null    object
#  7   published_date  507 non-null    datetime64[ns]
#  8   collected_at    507 non-null    datetime64[ns]
#  9   year            507 non-null    int32
#  10  month           507 non-null    int32
#  11  day             507 non-null    int32
#  12  weekday         507 non-null    object
# dtypes: datetime64[ns](2), int32(3), object(8)
# memory usage: 49.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["title"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["url"].duplicated().sum()
# Out:
# np.int64(0)

# %%
(df == "").sum()
# Out:
# source_name       0
# author            0
# title             0
# description       0
# url               0
# keyword           0
# language          0
# published_date    0
# collected_at      0
# year              0
# month             0
# day               0
# weekday           0
# dtype: int64

# %%
(df.apply(lambda col: col.astype(str).str.strip() == "")).sum()
# Out:
# source_name       0
# author            0
# title             0
# description       0
# url               0
# keyword           0
# language          0
# published_date    0
# collected_at      0
# year              0
# month             0
# day               0
# weekday           0
# dtype: int64

# %%
df["language"].value_counts()
# Out:
# language
# en    505
# fr      1
# nl      1
# Name: count, dtype: int64

# %%
df[df["language"] != "en"]
# Out:
#      source_name   author                                              title  \
# 223        GNews  Unknown  india raises taxes on diesel and jet fuel expo...
# 508  India Today  Unknown             delhi doesnt get rain it gets ambushed
#
#                                            description  \
# 223  india raises taxes on diesel and jet fuel expo...
# 508             delhi doesnt get rain it gets ambushed
#
#                                                    url               keyword  \
# 223  https://news.google.com/rss/articles/CBMimgFBV...  india, raises, taxes
# 508  https://www.indiatoday.in/diu/story/delhi-rain...     delhi, rain, gets
#
#     language      published_date        collected_at  year  month  day  \
# 223       fr 2026-07-16 03:47:14 2026-07-16 03:47:14  2026      7   16
# 508       nl 2026-07-09 14:20:17 2026-07-16 03:47:06  2026      7    9
#
#       weekday
# 223  Thursday
# 508  Thursday

# %%
df.loc[df["language"] == "fr", "language"] = "en"
df.loc[df["language"] == "nl", "language"] = "en"

# %%
df["language"].value_counts()
# Out:
# language
# en    507
# Name: count, dtype: int64

# %%
df["source_name"].value_counts()
# Out:
# source_name
# Hindustan Times    164
# GNews              119
# Times of India      98
# India Today         90
# NDTV                36
# Name: count, dtype: int64

# %%
print(df["published_date"].min())
print(df["published_date"].max())
# Out:
# 2026-07-09 14:20:17
# 2026-07-17 03:46:42

# %%
df["title_length"] = df["title"].str.len()
df["description_length"] = df["description"].str.len()

# %%
df["url"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["title"].duplicated().sum()
# Out:
# np.int64(0)

# %%
(df == "").sum()
# Out:
# source_name           0
# author                0
# title                 0
# description           0
# url                   0
# keyword               0
# language              0
# published_date        0
# collected_at          0
# year                  0
# month                 0
# day                   0
# weekday               0
# title_length          0
# description_length    0
# dtype: int64

# %%
(df.apply(lambda col: col.astype(str).str.strip() == "")).sum()
# Out:
# source_name           0
# author                0
# title                 0
# description           0
# url                   0
# keyword               0
# language              0
# published_date        0
# collected_at          0
# year                  0
# month                 0
# day                   0
# weekday               0
# title_length          0
# description_length    0
# dtype: int64

# %%
df["author"].value_counts().head(10)
# Out:
# author
# Unknown               409
# TOI WORLD DESK         17
# TOI SPORTS DESK        11
# TOI TECH DESK           9
# TOI BUSINESS DESK       8
# TOI NEWS DESK           5
# TNN                     5
# BARSHA DUTTA            4
# GLOBAL SPORTS DESK      3
# SURENDRA SINGH          3
# Name: count, dtype: int64

# %%
df[["title_length", "description_length"]].describe()
# Out:
#        title_length  description_length
# count    507.000000          507.000000
# mean      77.579882          165.530572
# std       19.331900          123.128779
# min       29.000000           38.000000
# 25%       67.000000           78.000000
# 50%       76.000000          112.000000
# 75%       86.000000          198.000000
# max      265.000000          457.000000

# %%
df["url"].str.startswith("http").value_counts()
# Out:
# url
# True    507
# Name: count, dtype: int64

# %%
df["url"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["title"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["title"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["url"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# source_name           0
# author                0
# title                 0
# description           0
# url                   0
# keyword               0
# language              0
# published_date        0
# collected_at          0
# year                  0
# month                 0
# day                   0
# weekday               0
# title_length          0
# description_length    0
# dtype: int64

# %%
print("========== DATA QUALITY REPORT ==========")
print(f"Total Records: {len(df)}")
print(f"Duplicate URLs: {df['url'].duplicated().sum()}")
print(f"Duplicate Titles: {df['title'].duplicated().sum()}")
print(f"Missing Values:\n{df.isnull().sum()}")
print(f"Languages:\n{df['language'].value_counts()}")
print("=========================================")
# Out:
# ========== DATA QUALITY REPORT ==========
# Total Records: 507
# Duplicate URLs: 0
# Duplicate Titles: 0
# Missing Values:
# source_name           0
# author                0
# title                 0
# description           0
# url                   0
# keyword               0
# language              0
# published_date        0
# collected_at          0
# year                  0
# month                 0
# day                   0
# weekday               0
# title_length          0
# description_length    0
# dtype: int64
# Languages:
# language
# en    507
# Name: count, dtype: int64
# ...

# %%
df.to_csv("../cleaned/news_clean.csv", index=False)

# %%
df.head(508)
# Out:
#         source_name         author  \
# 0             GNews        Unknown
# 1             GNews        Unknown
# 2             GNews        Unknown
# 3             GNews        Unknown
# 4             GNews        Unknown
# ..              ...            ...
# 504  Times of India   BARSHA DUTTA
# 505  Times of India  TOI TECH DESK
# 506     India Today        Unknown
# 507     India Today        Unknown
# 508     India Today        Unknown
#
#                                                  title  \
# 0    why the indopacific needs to be central to ind...
# 1    beyond political reshuffles renew education in...
# 2    india vs england doors closing down fast on ro...
# 3        is oneplus exiting india explained  the hindu
# 4    india to face malaysia syria iraq in afc u17 w...
# ..                                                 ...
# 504  erling haaland stunned fans when he mentioned ...
# 505  jeff bezos exwife mackenzie scott donates to u...
# ...
